# %% [markdown]
# # Matplotlib 基础

# %% [markdown]
# 在使用Numpy之前，需要了解一些画图的基础。
#
# Matplotlib是一个类似Matlab的工具包，主页地址为
#
# http://matplotlib.org
#
# 导入 matplotlib 和 numpy：

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## plot二维图
#
#     plot(y)
#     plot(x,y)
#     plot(x,y,format_string)
# 只给定y值，默认以下标为x轴

# %%
# %matplotlib inline
x = linspace(0,pi*2,50)
plot(sin(x))

# %% [markdown]
# 给定x和y值

# %%
plot(x,sin(x))

# %% [markdown]
# 多条数据线：

# %%
plot(x,sin(x),x,sin(2*x))
# Out:
# [<matplotlib.lines.Line2D at 0x1111bc10>,
#  <matplotlib.lines.Line2D at 0x1111bd10>]

# %% [markdown]
# 使用字符串，给定线条参数：

# %%
plot(x,sin(x),'r-^')

# %% [markdown]
# 多线条：

# %%
plot(x,sin(x),'b-o',x,sin(2 * x),'r-^')
# Out:
# [<matplotlib.lines.Line2D at 0x111a9990>,
#  <matplotlib.lines.Line2D at 0x111a9a90>]

# %% [markdown]
# 更多参数设置，请查阅帮助。事实上，字符串使用的格式与Matlab相同。

# %% [markdown]
# ## scatter 散点图

# %% [markdown]
#     scatter(x,y)
#     scatter(x,y,size)
#     scatter(x,y,size,color)
# 假设我们想画二维散点图：

# %%
plot(x,sin(x),'bo')

# %% [markdown]
# 可以使用scatter达到同样的效果：

# %%
scatter(x,sin(x))

# %% [markdown]
# 事实上，scatter函数与Matlab的用法相同，还可以指定它的大小，颜色等参数：

# %%
x = rand(200)
y = rand(200)
size = rand(200)*30
color = rand(200)
scatter(x,y,size,color)
#显示颜色
colorbar()

# %% [markdown]
# ## 多图

# %% [markdown]
# 使用figure()命令产生新的图像：

# %%
t = linspace(0,2*pi,50)
x = sin(t)
y = cos(t)
figure()
plot(x)
figure()
plot(y)

# %% [markdown]
# 或者使用subplot在一副图中画多幅子图：

# %% [markdown]
#      subplot(row,column,index)

# %%
subplot(1,2,1)
plot(x)
subplot(1,2,2)
plot(y)

# %% [markdown]
# ## 向图中添加数据

# %% [markdown]
# 默认多次plot会叠加

# %%
plot(x)
plot(y)

# %% [markdown]
# 可以跟Matlab类似用hold(False)关掉，这样新图会将原图覆盖：

# %%
plot(x)
hold(False)
plot(y)
#恢复原来设定
hold(True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:805: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:155: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   """

# %% [markdown]
# ## 标签

# %% [markdown]
# 可以在plot中加入label，使用legend加上图例：

# %%
plot(x, label='sin')
plot(y, label='cos')
legend()

# %% [markdown]
# 或者直接在legend中加入：

# %%
plot(x)
plot(y)
legend(['sin','cos'])

# %%
x1 = [1,2,3]
y1 = [5,7,4]
x2 = [1,2,3]
y2 = [10,12,14]
#创建图形
plt.figure()
plt.subplot(221) #创建第一个子图 2/2/1
plt.plot(x1,y1,'ro--')
plt.subplot(223)  #未知在2行2列第三个位子
plt.plot(x2,y2,'bo--')
#生成默认图例

plt.show()

# %% [markdown]
# ## 坐标轴，标题，网格

# %% [markdown]
# 可以设置坐标轴的标签和标题：

# %%
x1 = [1,2,3]
y1 = [5,7,4]
x2 = [1,2,3]
y2 = [10,12,14]
plt.figure()
plt.plot(x1,y1,'ro-',label = '进口')
plt.plot(x2,y2,'bo--',label = '出口')

#设置标题标签
plt.xlabel('月份')
plt.ylabel('美元/亿')
plt.title('进出口数据')
#设置范围
plt.xlim(0,6)
plt.ylim(0,15)

#设置刻度
plt.xticks([1,2,3,4,5,6],[str(i) + '月' for i in range(1,7)])
plt.yticks(np.arange(2,16,2),['200','300','400','500','600','700','800'])

#获取坐标轴信息
ax = plt.gca()
#设置边框
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('green')
#生成默认图例
plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

plt.show()

# %% [markdown]
# ## 直方图

# %% [markdown]
# ###### 从高斯分布随机生成1000个点得到的直方图：

# %%
 hist(randn(1000))
# Out:
# (array([   5.,   29.,   89.,  201.,  250.,  245.,  127.,   44.,    7.,    3.]),
#  array([-3.13367599, -2.45927745, -1.78487891, -1.11048037, -0.43608183,
#          0.23831671,  0.91271525,  1.58711379,  2.26151233,  2.93591087,
#          3.61030941]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# 更多例子请参考下列网站：
#
# http://matplotlib.org/gallery.html
